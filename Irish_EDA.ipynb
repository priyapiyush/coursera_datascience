# %% [markdown]
# <a href="https://colab.research.google.com/github/priyapiyush/coursera_datascience/blob/main/Irish_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# Replace '/path/to/your/dataset.csv' with the actual path to your file in Google Drive
df = pd.read_csv('/content/drive/MyDrive/ML_Nyberman/iris_extended.csv')

display(df.head())
# Out:
#   species  elevation soil_type  sepal_length  sepal_width  petal_length  \
# 0  setosa      161.8     sandy          5.16         3.41          1.64
# 1  setosa      291.4      clay          5.48         4.05          1.53
# 2  setosa      144.3     sandy          5.10         2.80          1.47
# 3  setosa      114.6      clay          4.64         3.44          1.53
# 4  setosa      110.9     loamy          4.85         2.87          1.23
#
#    petal_width  sepal_area  petal_area  sepal_aspect_ratio  ...  \
# 0         0.26     17.5956      0.4264            1.513196  ...
# 1         0.37     22.1940      0.5661            1.353086  ...
# 2         0.38     14.2800      0.5586            1.821429  ...
# 3         0.17     15.9616      0.2601            1.348837  ...
# 4         0.26     13.9195      0.3198            1.689895  ...
#
#    sepal_to_petal_length_ratio  sepal_to_petal_width_ratio  \
# 0                     3.146341                   13.115385
# ...

# %% [markdown]
# ## Step I: Display basic information about the dataset

# %% [markdown]
# Print the shape, info, and descriptive statistics of the DataFrame to understand its structure and content.

# %%
df.shape
print("Shape of DataFrame:")
print(df.shape)
print("\nInfo of the DataFrame:")
df.info()
print("\nDescriptive Statistics of the DataFrame:")
#df.describe()
display(df.describe())
# Out:
# Shape of DataFrame:
# (1200, 21)
#
# Info of the DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   species                          1200 non-null   object
#  1   elevation                        1200 non-null   float64
#  2   soil_type                        1200 non-null   object
#  3   sepal_length                     1200 non-null   float64
#  4   sepal_width                      1200 non-null   float64
#  5   petal_length                     1200 non-null   float64
#  6   petal_width                      1200 non-null   float64
#  7   sepal_area                       1200 non-null   float64
#  8   petal_area                       1200 non-null   float64
#  9   sepal_aspect_ratio               1200 non-null   float64
# ...

# %% [markdown]
# ## Step II: Check for missing values
#
# ###
# Identify if there are any missing values in the dataset and visualize them.

# %%
import missingno as msno
import matplotlib.pyplot as plt

# Calculate missing values per column
missing_values = df.isnull().sum()
print("Missing values per column:")
print(missing_values)

# Visualize missing values
msno.matrix(df)
plt.title('Missing Value Matrix')
plt.show()

msno.bar(df)
plt.title('Missing Value Bar Chart')
plt.show()
# Out:
# Missing values per column:
# species                            0
# elevation                          0
# soil_type                          0
# sepal_length                       0
# sepal_width                        0
# petal_length                       0
# petal_width                        0
# sepal_area                         0
# petal_area                         0
# sepal_aspect_ratio                 0
# petal_aspect_ratio                 0
# sepal_to_petal_length_ratio        0
# sepal_to_petal_width_ratio         0
# sepal_petal_length_diff            0
# sepal_petal_width_diff             0
# petal_curvature_mm                 0
# petal_texture_trichomes_per_mm2    0
# leaf_area_cm2                      0
# sepal_area_sqrt                    0
# petal_area_sqrt                    0
# area_ratios                        0
# dtype: int64

# %% [markdown]
# ## Step III. Visualize the distribution of numerical features
#
# ###
# Use histograms or box plots to visualize the distribution of numerical features.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

numerical_cols = df.select_dtypes(include=['float64', 'int64']).columns

plt.figure(figsize=(15, 20))
for i, col in enumerate(numerical_cols):
    plt.subplot(len(numerical_cols) // 3 + 1, 3, i + 1)
    sns.histplot(df[col], kde=True)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Step IV. Visualize the distribution of categorical features
#
# ###
# Use count plots or bar plots to visualize the distribution of categorical features.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

categorical_cols = df.select_dtypes(include=['object']).columns

plt.figure(figsize=(10, 5 * len(categorical_cols)))
for i, col in enumerate(categorical_cols):
    plt.subplot(len(categorical_cols), 1, i + 1)
    sns.countplot(data=df, x=col)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Step V: Explore the relationships between features
#
# ###
# Use scatter plots or pair plots to explore the relationships between features.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select a subset of numerical columns
numerical_subset = df[['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'petal_area']]

# Create a pair plot
sns.pairplot(numerical_subset)

# Display the pair plot
plt.show()

# %% [markdown]
# ## Step VI. Calculate the correlation matrix
#
# ###
# Calculate and visualize the correlation matrix to understand the linear relationships between numerical features.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select only the numerical columns
numerical_cols = df.select_dtypes(include=['float64', 'int64']).columns
numerical_df = df[numerical_cols]

# Calculate the correlation matrix
correlation_matrix = numerical_df.corr()

# Create a heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Numerical Features')
plt.show()

# %%
# Get the absolute values of the correlations
abs_correlation_matrix = correlation_matrix.abs()

# Stack the matrix and remove the diagonal (correlation of a variable with itself)
stacked_correlations = abs_correlation_matrix.stack()
sorted_correlations = stacked_correlations.sort_values(ascending=False)

# Remove self-correlations
sorted_correlations = sorted_correlations[sorted_correlations != 1.0]

# Get the top 5 strongest correlations
top_5_correlations = sorted_correlations.head(10) # Get top 10 as correlations appear in pairs

print("Top 5 strongest correlations:")
print(top_5_correlations)
# Out:
# Top 5 strongest correlations:
# sepal_area_sqrt             sepal_area                    0.997795
# sepal_area                  sepal_area_sqrt               0.997795
# area_ratios                 sepal_to_petal_width_ratio    0.983077
# sepal_to_petal_width_ratio  area_ratios                   0.983077
# petal_area_sqrt             petal_width                   0.980179
# petal_width                 petal_area_sqrt               0.980179
# petal_area_sqrt             petal_area                    0.976908
# petal_area                  petal_area_sqrt               0.976908
# petal_width                 petal_area                    0.972948
# petal_area                  petal_width                   0.972948
# dtype: float64

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
# * The dataset `df` contains 1200 rows and 21 columns, indicating a moderately sized dataset.
# * All columns in the dataset have no missing values, which simplifies the data cleaning process.
# * The dataset consists of 19 numerical columns (float64) and 2 categorical columns (object).
# * Histograms and KDE plots were generated for all numerical columns to visualize their distributions. Most numerical features appear to have roughly normal distributions, although some show slight skewness or multiple peaks, suggesting potential subtypes within the data or the need for transformations.
# * Count plots were generated for the two categorical columns (`species` and `soil_type`) to visualize their distributions. This showed the frequency of each category, indicating the balance or imbalance of classes.
# * A pair plot was created to visualize the relationships between a subset of numerical features: 'sepal\_length', 'sepal\_width', 'petal\_length', 'petal\_width', and 'petal\_area'. This revealed clear visual clusters, likely corresponding to different species, and highlighted strong positive correlations between petal dimensions.
# * A correlation matrix heatmap was generated for all numerical features, showing the linear relationships between them. This heatmap confirmed the strong positive correlations observed in the pair plot, particularly among petal measurements, and also showed some notable correlations between sepal measurements and other derived features. The strongest correlation found was between `sepal_area` and `sepal_area_sqrt` (correlation ~1.0), which is expected as one is a direct transformation of the other. Other strong correlations were observed between petal dimensions and area-related features.
#
# ### Insights or Next Steps
# * The absence of missing values is a significant advantage, allowing for immediate focus on feature engineering and modeling without the need for imputation.
# * The distinct clusters observed in the pair plots, especially for petal dimensions, suggest that these features will be highly informative for classification tasks (e.g., predicting species).
# * Highly correlated features, as identified by the correlation matrix, should be considered during feature selection to avoid multicollinearity issues in some models. For example, `sepal_area` and `sepal_area_sqrt` provide very similar information, and one could potentially be removed or combined.
# * Analyzing the distribution shapes can inform feature transformation decisions, such as using logarithmic transformations for skewed features if necessary for certain modeling algorithms.
# * Further steps could involve:
#     * **Feature Engineering**: Creating new features based on existing ones that might capture more complex relationships.
#     * **Data Preprocessing**: Scaling or normalizing numerical features, and encoding categorical features for use in machine learning models.
#     * **Model Selection and Training**: Choosing appropriate machine learning models for the task (e.g., classification for predicting species) and training them on the prepared data.
#     * **Model Evaluation**: Assessing the performance of the trained models using relevant metrics.
